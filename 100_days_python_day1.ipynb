# %% [markdown]
# <a href="https://colab.research.google.com/github/roshankumarsa/100days-Python-Challenge---Code-with-Harry-Youtube/blob/main/100_days_python_day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
print(5)
print(12.5)
# Out:
# Hello World
# 5
# 12.5

# %% [markdown]
# Programming is a way to tell computers what to do

# %%
# Day 2

# import Entire module
import math
print(math.sqrt(25))
# Out:
# 5.0

# %%
#import specific components

from math import sqrt, pi
print(sqrt(25))
print(pi)
# Out:
# 5.0
# 3.141592653589793

# %%
#Import wit an alias

import pandas as pd
import numpy as np
